# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjana2343/git333/blob/main/graphs_plt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
iris=pd.read_csv('/content/iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
iris=pd.read_csv('/content/iris.csv')
x=iris['SepalWidthCm']
y=iris['SepalLengthCm']
plt.scatter(x,y)
plt.xlabel('SepalWidthCm')
plt.ylabel('SepalLengthCm')
plt.title('scatter plot')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
iris=pd.read_csv('/content/iris.csv')
x=iris['SepalWidthCm']
y=iris['SepalLengthCm']
color={'Iris-setosa':'red','Iris-virginica':'blue','Iris-versicolor':'green'}
species_color=iris['Species'].map(color)
plt.scatter(x,y,c=species_color)
plt.xlabel("SepalWidthCm")
plt.ylabel("SepalLengthCm")
plt.title("scatter plot")
plt.show()

# %% [markdown]
# 3)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
iris=pd.read_csv('/content/iris.csv')
x=iris['SepalWidthCm']
y=iris['SepalLengthCm']
species_counts=iris['Species'].value_counts()
plt.bar(species_counts.index,species_counts.values,color="green")
plt.title("Number of flowers by species")
plt.xlabel("species")
plt.ylabel("count")
plt.grid(axis='y')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
iris=pd.read_csv('/content/iris.csv')
plt.hist(iris['PetalLengthCm'], bins=10, color='lightgreen', edgecolor='black')
plt.title("Distribution of Petal Length")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
iris=pd.read_csv('/content/iris.csv')
x=iris['PetalLengthCm']
species = iris['Species'].unique()
data = [iris[iris['Species'] == s]['PetalLengthCm'] for s in species]
plt.boxplot(data, labels=species)
plt.title("Petal Length by Species")
plt.xlabel("Species")
plt.ylabel("Petal Length (cm)")
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-1583632197.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=species)
