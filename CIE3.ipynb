# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjana2343/git333/blob/main/CIE3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/auto-mpg (2).csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
x=df[['acceleration']]
x
y=df['weight']
y
# Out:
# 0      3504
# 1      3693
# 2      3436
# 3      3433
# 4      3449
#        ...
# 393    2790
# 394    2130
# 395    2295
# 396    2625
# 397    2720
# Name: weight, Length: 398, dtype: int64

# %%
sns.scatterplot(x='acceleration',y='weight',data=df)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
x_train
x_test
y_train
y_test
# Out:
# 378    2125
# 36     3302
# 106    4499
# 95     4951
# 309    2144
#        ...
# 275    3140
# 375    1980
# 296    2670
# 394    2130
# 208    3940
# Name: weight, Length: 80, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
x_pred=lr.predict(x_train)
print(x_pred)
print(y_pred)
# Out:
# [2714.94743508 2767.17310878 3158.86566152 2545.21399555 3263.31700892
#  3041.3578957  3576.67105111 2910.79371145 3080.52715097 3132.75282467
#  3198.03491679 2949.96296672 3002.18864042 3198.03491679 3328.59910104
#  3198.03491679 3916.13793016 2519.1011587  2140.46502439 3132.75282467
#  2728.0038535  3198.03491679 3785.57374591 3211.09133522 3328.59910104
#  3524.44537741 2871.62445617 3132.75282467 2936.9065483  2610.49608768
#  2832.4552009  3132.75282467 2610.49608768 3785.57374591 2871.62445617
#  2127.40860596 3002.18864042 3524.44537741 2884.6808746  3459.16328529
#  2806.34236405 3459.16328529 2545.21399555 2192.69069808 3354.71193789
#  2675.7781798  3263.31700892 2806.34236405 2858.56803775 2741.06027193
#  2949.96296672 3067.47073255 3550.55821426 2284.08562706 2675.7781798
#  3393.88119317 3145.80924309 3145.80924309 3328.59910104 2349.36771918
#  3132.75282467 3132.75282467 3132.75282467 3459.16328529 3302.48626419
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print('Mean Squared Error:',mse)
print('Mean Absolute Error:',mae)
print('R2 Score:',r2)
# Out:
# Mean Squared Error: 588404.5005553954
# Mean Absolute Error: 649.584396078319
# R2 Score: 0.13762292429539025

# %%
import numpy as np
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
print('Root Mean Squared Error:',rmse)
# Out:
# Root Mean Squared Error: 767.0752900174763

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,x_pred,color='blue')
plt.title('Training Data')
plt.xlabel('acceleration')
plt.ylabel('weight')
plt.show()
